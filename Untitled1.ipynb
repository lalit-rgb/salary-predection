# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import numpy as np
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
def exp(s):
    if s == "Bachelor's":
        return 0
    elif s == "Master's":
        return 1
    else: return 2

# %%
s = df['Education Level'].apply(exp)
s
# Out:
# 0      0
# 1      1
# 2      2
# 3      0
# 4      1
#       ..
# 370    0
# 371    1
# 372    0
# 373    0
# 374    2
# Name: Education Level, Length: 375, dtype: int64

# %%
corr_var=df.corr()
print(corr_var)
plt.figure(figsize=(10,7.5))
sns.heatmap(corr_var, annot=True, cmap='BuPu')
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.979128  0.922335
# Years of Experience  0.979128             1.000000  0.930338
# Salary               0.922335             0.930338  1.000000
# <AxesSubplot:>

# %%
df['ed'] = s

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary  ed
# 0                    5.0   90000.0   0
# 1                    3.0   65000.0   1
# 2                   15.0  150000.0   2
# 3                    7.0   60000.0   0
# 4                   20.0  200000.0   1
# ..                   ...       ...  ..
# 370                  8.0   85000.0   0
# 371                 19.0  170000.0   1
# 372                  2.0   40000.0   0
# 373                  7.0   90000.0   0
# 374                 15.0  150000.0   2
#
# [375 rows x 7 columns]

# %%
df.head(50)
# Out:
#      Age  Gender Education Level                 Job Title  \
# 0   32.0    Male      Bachelor's         Software Engineer
# 1   28.0  Female        Master's              Data Analyst
# 2   45.0    Male             PhD            Senior Manager
# 3   36.0  Female      Bachelor's           Sales Associate
# 4   52.0    Male        Master's                  Director
# 5   29.0    Male      Bachelor's         Marketing Analyst
# 6   42.0  Female        Master's           Product Manager
# 7   31.0    Male      Bachelor's             Sales Manager
# 8   26.0  Female      Bachelor's     Marketing Coordinator
# 9   38.0    Male             PhD          Senior Scientist
# 10  29.0    Male        Master's        Software Developer
# 11  48.0  Female      Bachelor's                HR Manager
# 12  35.0    Male      Bachelor's         Financial Analyst
# 13  40.0  Female        Master's           Project Manager
# 14  27.0    Male      Bachelor's      Customer Service Rep
# 15  44.0    Male      Bachelor's        Operations Manager
# 16  33.0  Female        Master's         Marketing Manager
# 17  39.0    Male             PhD           Senior Engineer
# 18  25.0  Female      Bachelor's          Data Entry Clerk
# 19  51.0    Male      Bachelor's            Sales Director
# 20  34.0  Female        Master's          Business Analyst
# 21  47.0    Male        Master's          VP of Operations
# 22  30.0    Male      Bachelor's                IT Support
# 23  36.0  Female      Bachelor's                 Recruiter
# 24  41.0    Male        Master's         Financial Manager
# 25  28.0  Female      Bachelor's   Social Media Specialist
# 26  37.0  Female        Master's          Software Manager
# 27  24.0    Male      Bachelor's          Junior Developer
# 28  43.0  Female             PhD         Senior Consultant
# 29  33.0    Male        Master's          Product Designer
# 30  50.0    Male      Bachelor's                       CEO
# 31  31.0  Female      Bachelor's                Accountant
# 32  29.0    Male        Master's            Data Scientist
# 33  39.0  Female      Bachelor's      Marketing Specialist
# 34  46.0    Male             PhD            Senior Manager
# 35  27.0    Male      Bachelor's          Technical Writer
# 36  35.0  Female      Bachelor's             HR Generalist
# 37  42.0    Male        Master's          Project Engineer
# 38  26.0  Female      Bachelor's      Customer Success Rep
# 39  49.0    Male      Bachelor's           Sales Executive
# 40  34.0  Female        Master's               UX Designer
# 41  48.0    Male        Master's       Operations Director
# 42  30.0    Male      Bachelor's          Network Engineer
# 43  36.0  Female      Bachelor's  Administrative Assistant
# 44  41.0    Male        Master's       Strategy Consultant
# 45  28.0  Female      Bachelor's                Copywriter
# 46  32.0    Male      Bachelor's           Account Manager
# 47  45.0  Female        Master's     Director of Marketing
# 48  38.0    Male             PhD          Senior Scientist
# 49  25.0    Male      Bachelor's         Help Desk Analyst
#
#     Years of Experience    Salary  ed
# 0                   5.0   90000.0   0
# 1                   3.0   65000.0   1
# 2                  15.0  150000.0   2
# 3                   7.0   60000.0   0
# 4                  20.0  200000.0   1
# 5                   2.0   55000.0   0
# 6                  12.0  120000.0   1
# 7                   4.0   80000.0   0
# 8                   1.0   45000.0   0
# 9                  10.0  110000.0   2
# 10                  3.0   75000.0   1
# 11                 18.0  140000.0   0
# 12                  6.0   65000.0   0
# 13                 14.0  130000.0   1
# 14                  2.0   40000.0   0
# 15                 16.0  125000.0   0
# 16                  7.0   90000.0   1
# 17                 12.0  115000.0   2
# 18                  0.0   35000.0   0
# 19                 22.0  180000.0   0
# 20                  5.0   80000.0   1
# 21                 19.0  190000.0   1
# 22                  2.0   50000.0   0
# 23                  9.0   60000.0   0
# 24                 13.0  140000.0   1
# 25                  3.0   45000.0   0
# 26                 11.0  110000.0   1
# 27                  1.0   40000.0   0
# 28                 15.0  140000.0   2
# 29                  6.0   90000.0   1
# 30                 25.0  250000.0   0
# 31                  4.0   55000.0   0
# 32                  3.0   75000.0   1
# 33                 10.0   65000.0   0
# 34                 20.0  170000.0   2
# 35                  2.0   45000.0   0
# 36                  7.0   60000.0   0
# 37                 14.0  115000.0   1
# 38                  1.0   40000.0   0
# 39                 21.0  160000.0   0
# 40                  5.0   80000.0   1
# 41                 18.0  190000.0   1
# 42                  3.0   60000.0   0
# 43                  8.0   45000.0   0
# 44                 13.0  130000.0   1
# 45                  2.0   40000.0   0
# 46                  5.0   75000.0   0
# 47                 16.0  180000.0   1
# 48                 11.0  120000.0   2
# 49                  0.0   35000.0   0

# %%
fd = df.loc[:,['Years of Experience','ed','Salary','Age']]

# %%
fd = fd.dropna()
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 374
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years of Experience  373 non-null    float64
#  1   ed                   373 non-null    int64
#  2   Salary               373 non-null    float64
#  3   Age                  373 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 14.6 KB

# %%
corr_var=df.corr()
print(corr_var)
plt.figure(figsize=(10,7.5))
sns.heatmap(corr_var, annot=True, cmap='BuPu')
# Out:
#                           Age  Years of Experience    Salary        ed
# Age                  1.000000             0.979128  0.922335  0.562693
# Years of Experience  0.979128             1.000000  0.930338  0.590863
# Salary               0.922335             0.930338  1.000000  0.670371
# ed                   0.562693             0.590863  0.670371  1.000000
# <AxesSubplot:>

# %%
x = fd.loc[:,['Years of Experience','Age','ed']]
x
# Out:
#      Years of Experience   Age  ed
# 0                    5.0  32.0   0
# 1                    3.0  28.0   1
# 2                   15.0  45.0   2
# 3                    7.0  36.0   0
# 4                   20.0  52.0   1
# ..                   ...   ...  ..
# 370                  8.0  35.0   0
# 371                 19.0  43.0   1
# 372                  2.0  29.0   0
# 373                  7.0  34.0   0
# 374                 15.0  44.0   2
#
# [373 rows x 3 columns]

# %%
y = fd.loc[:,'Salary']
y
# Out:
# 0       90000.0
# 1       65000.0
# 2      150000.0
# 3       60000.0
# 4      200000.0
#          ...
# 370     85000.0
# 371    170000.0
# 372     40000.0
# 373     90000.0
# 374    150000.0
# Name: Salary, Length: 373, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=1)

# %%
model = LinearRegression()

# %%
x_train
# Out:
#      Years of Experience   Age  ed
# 345                  4.0  33.0   0
# 187                  9.0  34.0   0
# 27                   1.0  24.0   0
# 292                  2.0  29.0   0
# 73                   2.0  28.0   0
# ..                   ...   ...  ..
# 204                  7.0  36.0   0
# 256                  6.0  34.0   1
# 72                  16.0  45.0   2
# 236                  9.0  37.0   0
# 37                  14.0  42.0   1
#
# [298 rows x 3 columns]

# %%
y_train
# Out:
# 345     60000.0
# 187    100000.0
# 27      40000.0
# 292     40000.0
# 73      40000.0
#          ...
# 204     90000.0
# 256    100000.0
# 72     190000.0
# 236    100000.0
# 37     115000.0
# Name: Salary, Length: 298, dtype: float64

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 374
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years of Experience  373 non-null    float64
#  1   ed                   373 non-null    int64
#  2   Salary               373 non-null    float64
#  3   Age                  373 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 14.6 KB

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 3641.54225025  2165.94748515 13692.22457997]

# %%
model.intercept_
# Out:
# -23473.998183812757

# %%
predictions = model.predict(x_test)

# %%
predictions
# Out:
# array([ 61878.08510701,  40814.07365057, 116311.44021073,  62568.43782705,
#        121941.52519418,  48787.51087111, 169091.79579741, 178540.82778305,
#        108939.65333426,  50263.10563621,  81466.50179835,  46621.56338596,
#        104696.46073994, 124284.87743128,  46621.56338596,  44455.61590082,
#        157476.81632661, 106862.40822508, 170656.09293848,  50263.10563621,
#        124886.52777535,  52429.05312136, 128528.0700256 , 157476.81632661,
#        153835.27407636, 175678.34062882,  79990.90703325, 172733.33804766,
#         46621.56338596,  66209.9800773 , 172822.04042363, 159642.76381176,
#         51995.17438537, 164848.60320308,  54595.00060651, 161207.06095283,
#        129402.01444663,  54595.00060651, 132080.90989987, 151669.32659121,
#         83632.44928349,  54595.00060651, 120554.63280505, 153835.27407636,
#         79990.90703325, 146039.24160776, 126362.12254045,  30674.68894487,
#        157476.81632661, 165538.95592313,  54595.00060651, 142220.29460557,
#        159731.46618773,  54595.00060651,  52429.05312136, 103132.16359886,
#        104696.46073994,  75659.01206295,  46621.56338596, 157476.81632661,
#        186514.2650036 , 108939.65333426,  40123.72093052,  54595.00060651,
#        127837.71730555, 145950.53923179,  56760.94809166,  65519.62735726,
#        104696.46073994,  48787.51087111, 167014.55068823, 160428.00585682,
#         93771.83398919, 172822.04042363,  30674.68894487])

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 2.,  0.,  3., 12., 12., 24., 14.,  4.,  1.,  3.]),
#  array([-46362.12254045, -38357.05430748, -30351.98607451, -22346.91784153,
#         -14341.84960856,  -6336.78137559,   1668.28685738,   9673.35509035,
#          17678.42332333,  25683.4915563 ,  33688.55978927]),
#  <BarContainer object of 10 artists>)

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 10729.318978306368

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 208239812.26388156

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 14430.516701209335

# %%
sns.set(style="whitegrid")
ax = sns.lineplot(y_test, predictions)
  
# giving title to the plot
plt.title('Graph')
  
# function to show plot
plt.show()
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
r2_score(y_test, predictions)*100
# Out:
# 91.97137049905699

# %%
sns.pairplot(fd)
